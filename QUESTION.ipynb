# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Read the Excel file
df = pd.read_excel("./AAQOL.xlsx")




# Get and print the column names
columns = df.columns

# Display the first few rows of the dataframe
df
# Out:
#      RespondentID  CollectorID  \
# 0      4875415311     89154797
# 1      4875400418     89154350
# 2      4873390597     89104176
# 3      4873354523     89103223
# 4      4873338626     89102398
# ..            ...          ...
# 869    4489744664     80347661
# 870    4489732978     79629078
# 871    4489639434     80345008
# 872    4489589836     80343673
# 873    4489409149     79629078
#
#                 Q1 How did you hear about this survey?  \
# 0                                Conversation Over Tea
# 1                                Conversation Over Tea
# 2                                Conversation Over Tea
# 3                                Conversation Over Tea
# 4                                Conversation Over Tea
# ..                                                 ...
# 869  Asian Real Estate Association of America (AREA...
# 870                               City of Austin staff
# 871  St. John Branch, Public Library:Â  835 W Rundb...
# ...

# %%
print(df.describe())
# Out:
#        RespondentID   CollectorID  \
# count  8.740000e+02  8.740000e+02
# mean   4.625481e+09  8.254922e+07
# std    1.027605e+08  2.757575e+06
# min    4.489409e+09  7.962908e+07
# 25%    4.518568e+09  7.962908e+07
# 50%    4.593282e+09  8.212761e+07
# 75%    4.729812e+09  8.554674e+07
# max    4.875415e+09  8.915480e+07
#
#        Q2 What is your age? (Please enter numerical number) - Open-Ended Response  \
# count                                         862.000000
# mean                                           43.906032
# std                                            16.891310
# min                                             0.000000
# 25%                                            34.000000
# 50%                                            41.000000
# 75%                                            53.000000
# max                                            95.000000
#
# ...

# %%
sns.pairplot(df)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the 'Q1 How did you hear about this survey?' column to string
df['Q1 How did you hear about this survey?'] = df['Q1 How did you hear about this survey?'].astype(str)

# Plot the histogram
sns.histplot(df['Q1 How did you hear about this survey?'], bins=20, kde=True)
plt.title('Question and Answer')
plt.xlabel('Q1 How did you hear about this survey?')
plt.show()

# %%
# Data Visualization
# Visualize the distribution of the target variable ('Q1 How did you hear about this survey?')
sns.countplot(x='Q2 What is your age? (Please enter numerical number) - Open-Ended Response', data=df)
plt.title('question bank')
plt.show()

#'Relationship between Q3 What is your gender? (Please choose one) and Q1 How did you hear about this survey? '
#
# Relationship between gender and how participants heard about the survey
sns.countplot(x='Q3 What is your gender? (Please choose one)', hue='Q2 What is your age? (Please enter numerical number) - Open-Ended Response', data=df)
plt.title('Relationship between Gender and Survey Source')
plt.show()

# Visualize the distribution of ''
## Visualize the distribution of 'Q3 What is your gender? (Please choose one)'
#which sex have 
sns.countplot(x='Q3 What is your gender? (Please choose one)', data=df)
plt.title('Distribution of Gender Responses')
plt.show()
